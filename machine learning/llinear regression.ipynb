# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('headbrain.csv')
print(data.size)
print(data.shape)
data.head()
# Out:
# 948
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = data['Head Size(cm^3)'].values
Y = data['Brain Weight(grams)'].values

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
n=len(X)

# %%
X = X.reshape((n, 1))
reg = LinearRegression()
reg = reg.fit(X, Y)

# %%
plt.plot(X, reg.predict(X), color='green',linewidth=4, label='Regression Line')
# Ploting Scatter Points
plt.scatter(X, Y, c='brown', label='Scatter Plot')
plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

# %%
# Make predictions using the trained model
Y_pred = reg.predict(X)

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(Y, Y_pred)
# Calculate R-squared (R2) score
r2_score = r2_score(Y, Y_pred)

# %%
ms=np.sqrt(mse)

# %%
# Print the results
print(f"Mean Squared Error (MSE):{ms}")
print(f"R-squared (R2) Score: {r2_score}")
# Out:
# Mean Squared Error (MSE):72.1206213783709
# R-squared (R2) Score: 0.639311719957
